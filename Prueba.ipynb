# %% [markdown]
# <a href="https://colab.research.google.com/github/Vixuz144/Simulacion2/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descargar libreria por github

# %%
! git clone https://github.com/Vixuz144/Simulacion2.git
# Out:
# Cloning into 'Simulacion2'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 72 (delta 26), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (72/72), 9.14 MiB | 9.23 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
from Simulacion2 import funcionprueba

# %%
print(funcionprueba.f(1,2,3,4))
# Out:
# 10

# %%
from Simulacion2 import retratofase1 as rf1

# %%
a, b, c, d = 1, 1, 0, 1
rf1.lacosa(a,b,c,d)

# %% [markdown]
# ##Descargar libreria por pip install

# %%
pip install -i https://test.pypi.org/simple/ prueba-pypi-Vixuz144==0.0.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
from prueba_pypi_Vixuz144.graficas import retratofase1 as rf11
from prueba_pypi_Vixuz144.saludo.hola import hola
hola()
a, b, c, d = 1, 1, 0, 1
rf11.lacosa(a,b,c,d)
# Out:
# Buenas profe Medel, que tal lo ve?
